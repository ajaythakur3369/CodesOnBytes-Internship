# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/CodesOnBytes-Internship/blob/main/Data_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - Data Training**
# ## **Developed By - Ajay Thakur (ajaythakur3369@gmail.com)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota**
# ## **Submitted To - CodesOnBytes**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/CodesOnBytes-Internship)**

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# Train a simple linear regression model on the dataset and predict the output
#
# **Training Dataset -** https://docs.google.com/spreadsheets/d/e/2PACX-1vRTK2NvcndgPX41Czu6Ft2Ho_nE-z50BgTqdzwFW0rsJ2nvyNLe2DoIg1COzUbgw80oaRBjfy5-WtFk/pubhtml

# %% [markdown]
# # **Let's Begin !**

# %%
# Import all necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
train_data = pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vRTK2NvcndgPX41Czu6Ft2Ho_nE-z50BgTqdzwFW0rsJ2nvyNLe2DoIg1COzUbgw80oaRBjfy5-WtFk/pubhtml")
set1 = train_data[0]
set1
# Out:
#      Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0             1          x            y
# 1             2         24  21.54945196
# 2             3         50  47.46446305
# 3             4         15  17.21865634
# 4             5         38  36.58639803
# ..          ...        ...          ...
# 696         697         58  58.59500642
# 697         698         93  94.62509374
# 698         699         82  88.60376995
# 699         700         66  63.64868529
# 700         701         97   94.9752655
#
# [701 rows x 3 columns]

# %%
# To access the file, access the Drive from Colab
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
set1.to_csv("/content/drive/MyDrive/Colab_Notebook/Internship_Name/CodesOnBytes/File_Name/Training_dataset.csv")
train_data = pd.read_csv("/content/drive/MyDrive/Colab_Notebook/Internship_Name/CodesOnBytes/File_Name/Training_dataset.csv")
train_data
# Out:
#      Unnamed: 0.1  Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0               0           1          x            y
# 1               1           2         24  21.54945196
# 2               2           3         50  47.46446305
# 3               3           4         15  17.21865634
# 4               4           5         38  36.58639803
# ..            ...         ...        ...          ...
# 696           696         697         58  58.59500642
# 697           697         698         93  94.62509374
# 698           698         699         82  88.60376995
# 699           699         700         66  63.64868529
# 700           700         701         97   94.9752655
#
# [701 rows x 4 columns]

# %%
trains = train_data.drop("Unnamed: 0", axis = 1)
trains.columns = trains.iloc[0]
train_data = trains.drop(0)
train_data
# Out:
# 0      0   x            y
# 1      1  24  21.54945196
# 2      2  50  47.46446305
# 3      3  15  17.21865634
# 4      4  38  36.58639803
# 5      5  87  87.28898389
# ..   ...  ..          ...
# 696  696  58  58.59500642
# 697  697  93  94.62509374
# 698  698  82  88.60376995
# 699  699  66  63.64868529
# 700  700  97   94.9752655
#
# [700 rows x 3 columns]

# %%
train_dataset = train_data.dropna(subset = ['y'])
train_dataset
# Out:
# 0      0   x            y
# 1      1  24  21.54945196
# 2      2  50  47.46446305
# 3      3  15  17.21865634
# 4      4  38  36.58639803
# 5      5  87  87.28898389
# ..   ...  ..          ...
# 696  696  58  58.59500642
# 697  697  93  94.62509374
# 698  698  82  88.60376995
# 699  699  66  63.64868529
# 700  700  97   94.9752655
#
# [699 rows x 3 columns]

# %%
x_train = train_dataset[["x"]].astype(float)
y_train = train_dataset[["y"]].astype(float)

# %%
plt.scatter(x_train, y_train, s = 5)
plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel('X', fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel('Y', fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.show()

# %%
chart = sns.regplot(x = x_train, y = y_train, scatter_kws = {'s':30, 'facecolor':'white'}, line_kws = {'color':'red'})
plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel('x', fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel('y', fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("The regression line of y on x", fontname = 'serif', fontsize = 16)
plt.show()

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m = model.intercept_
c = model.coef_
m, c
# Out:
# (array([-0.10726546]), array([[1.00065638]]))

# %%
yhat = model.predict(x_train)
x_train
# Out:
# 0       x
# 1    24.0
# 2    50.0
# 3    15.0
# 4    38.0
# 5    87.0
# ..    ...
# 696  58.0
# 697  93.0
# 698  82.0
# 699  66.0
# 700  97.0
#
# [699 rows x 1 columns]

# %%
x_train.shape
# Out:
# (699, 1)

# %%
x_train = x_train.squeeze()
yhat = yhat.squeeze()

# %%
index = [i for i in range(1, 700)]
plt.plot(index, y_train , color = "blue" , linewidth = 2, linestyle = '-')
plt.plot(index, yhat , color = "yellow", linewidth = 1, linestyle = '-')
plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel('Index', fontname = 'serif', fontsize = 14)
plt.xticks(np.arange(0, 330, step = 30), fontname = 'serif', rotation = 90)
plt.ylabel('y-values', fontname = 'serif', fontsize = 14)
plt.yticks(np.arange(0, 120, step = 20), fontname = 'serif')
plt.title("Actual vs. Predicted", fontname = 'serif', fontsize = 16)
plt.show()

# %%
from sklearn import metrics

# %%
print("MSE = ", metrics.mean_squared_error(yhat, y_train))
print("R^2 = ", metrics.r2_score(yhat, y_train))
# Out:
# MSE =  7.867752733487687
# R^2 =  0.9906142588882534

# %%
plt.scatter(y_train, yhat, s = 7, color = 'red')
plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel('Y-Train', fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel('Predicted Y', fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.show()

# %%
show = pd.DataFrame({"Training value": x_train, "Predicted value": yhat})

# %%
show
# Out:
#      Training value  Predicted value
# 1              24.0        23.908488
# 2              50.0        49.925554
# 3              15.0        14.902580
# 4              38.0        37.917677
# 5              87.0        86.949840
# ..              ...              ...
# 696            58.0        57.930805
# 697            93.0        92.953778
# 698            82.0        81.946558
# 699            66.0        65.936056
# 700            97.0        96.956404
#
# [699 rows x 2 columns]
